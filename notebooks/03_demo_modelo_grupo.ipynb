# %% [markdown]
# # 03 - Demo do modelo do grupo
#
# Antes de rodar este notebook, edite `src/models/group_model.py` para retornar uma instancia do modelo atribuido ao seu grupo. Veja os exemplos comentados no arquivo.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from data.load_tabarena import load_task, RECOMMENDED_TASK_IDS
from src.models.group_model import build_group_model
from src.pipeline.split import stratified_split
from src.pipeline.evaluate import fit_predict_evaluate

# %%
import torch

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch Version: 2.12.0+cu132
# CUDA Available: True
# GPU Device: NVIDIA GeForce RTX 5060 Ti

# %%
ds = load_task(RECOMMENDED_TASK_IDS[7])
X_train, X_test, y_train, y_test = stratified_split(ds.X, ds.y, seed=42)

model = build_group_model(seed=42)
metrics = fit_predict_evaluate(model, X_train, y_train, X_test, y_test)
print(f'AUC={metrics.auc_ovo:.4f}, ACC={metrics.accuracy:.4f}, time={metrics.fit_time_s + metrics.predict_time_s:.1f}s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 ds = load_task(RECOMMENDED_TASK_IDS[6])
# ----> 2 X_train, X_test, y_train, y_test = stratified_split(ds.X, ds.y, seed=42)
#       3
#       4 model = build_group_model(seed=42)
#       5 metrics = fit_predict_evaluate(model, X_train, y_train, X_test, y_test)
#
# File ~\Downloads\machine_learning_2026_leandro\src\pipeline\split.py:20, in stratified_split(X, y, seed, test_size)
#      13 def stratified_split(
#      14     X: pd.DataFrame,
#      15     y: np.ndarray,
#      16     seed: int = DEFAULT_SEED,
#      17     test_size: float = DEFAULT_TEST_SIZE,
#      18 ) -> tuple[pd.DataFrame, pd.DataFrame, np.ndarray, np.ndarray]:
#      19     """Split 70/30 estratificado por classe."""
# ---> 20     X_train, X_test, y_train, y_test = train_test_split(
#      21         X,
#      22         y,
#      23         test_size=test_size,
#      24         random_state=seed,
#      25         stratify=y,
#      26     )
#      27     return X_train, X_test, y_train, y_test
#
# File c:\Users\Administrador\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\Administrador\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\sklearn\model_selection\_split.py:2940, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2936         CVClass = ShuffleSplit
#    2938     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2940     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2942 train, test = ensure_common_namespace_device(arrays[0], train, test)
#    2944 return list(
#    2945     chain.from_iterable(
#    2946         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2947     )
#    2948 )
#
# File c:\Users\Administrador\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\sklearn\model_selection\_split.py:1927, in BaseShuffleSplit.split(self, X, y, groups)
#    1897 """Generate indices to split data into training and test set.
#    1898
#    1899 Parameters
#    (...)   1924 to an integer.
#    1925 """
#    1926 X, y, groups = indexable(X, y, groups)
# -> 1927 for train, test in self._iter_indices(X, y, groups):
#    1928     yield train, test
#
# File c:\Users\Administrador\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\sklearn\model_selection\_split.py:2342, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2340 class_counts = np.bincount(y_indices)
#    2341 if np.min(class_counts) < 2:
# -> 2342     raise ValueError(
#    2343         "The least populated class in y has only 1"
#    2344         " member, which is too few. The minimum"
#    2345         " number of groups for any class cannot"
#    2346         " be less than 2."
#    2347     )
#    2349 if n_train < n_classes:
#    2350     raise ValueError(
#    2351         "The train_size = %d should be greater or "
#    2352         "equal to the number of classes = %d" % (n_train, n_classes)
#    2353     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.
