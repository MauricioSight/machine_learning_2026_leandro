# %% [markdown]
# # 01 - EDA dos 30 datasets do TabArena-v0.1
#
# Carrega os 30 datasets configurados em `data/load_tabarena.py` e gera tabela-resumo com tamanho, numero de classes, proporcao numerico/categorico e presenca de missing values. A partir dessa tabela definimos os regimes para a analise da Etapa 2.

# %%
import sys
from pathlib import Path
import openml
from openml.tasks import TaskType
sys.path.append(str(Path('..').resolve()))

from data.load_tabarena import summarize, RECOMMENDED_TASK_IDS

# %%
metadata = summarize(RECOMMENDED_TASK_IDS)
metadata
# Out:
#     task_id                              name  n_samples  n_features  \
# 0    359955  blood-transfusion-service-center        748           4
# 1    359968                             churn       5000          20
# 2    168757                          credit-g       1000          20
# 3        37                          diabetes        768           8
# 4    363698                QSAR_fish_toxicity        907           6
# 5    363612                airfoil_self_noise       1503           5
# 6    363615  Another-Dataset-on-used-Fiat-500       1538           7
# 7    363675     healthcare_insurance_expenses       1338           6
# 8    363618                    bank-marketing      45211          13
# 9    363619               Bank_Customer_Churn      10000          10
# 10   363625     concrete_compressive_strength       1030           8
# 11   363632             E-CommereShippingData      10999          10
# 12   363672                Food_Delivery_Time      45451           9
# 13   363613            Amazon_employee_access      32769           9
# 14   363676                             heloc      10459          23
# 15     3892                     hiva_agnostic       4229        1617
# 16     3688                            houses      20640           8
# 17   363681  in_vehicle_coupon_recommendation      12684          24
# 18   363685              maternal_health_risk       1014           6
# 19   363686                     miami_housing      13776          15
# 20   359956                       qsar-biodeg       1055          41
# 21       45                            splice       3190          60
# 22   233211                          diamonds      53940           9
# 23     3492                  monks-problems-1        556           6
# 24     3493                  monks-problems-2        601           6
# 25     3494                  monks-problems-3        554           6
# 26     3512                 synthetic_control        600          60
# 27     3549            analcatdata_authorship        841          70
# 28     3560                  analcatdata_dmft        797           4
# 29     3583                     rmftsa_ladata        508          10
#
#     n_classes  n_categorical  has_missing  regime
# 0           2              0        False   small
# 1           2              4        False  medium
# 2           2             13        False  medium
# 3           2              0        False   small
# 4         827              0        False   small
# 5        1456              1        False  medium
# 6         222              1        False  medium
# 7        1337              3        False  medium
# 8           2              7        False   large
# 9           2              4        False   large
# 10        938              0        False  medium
# 11          2              4        False   large
# 12         45              3        False   large
# 13          2              9        False   large
# 14          2              0        False   large
# 15          2              0        False  medium
# 16          2              0        False   large
# 17          2             21        False   large
# 18          3              0        False  medium
# 19       2106              1        False   large
# 20          2              0        False  medium
# 21          3             60        False  medium
# 22      11602              3        False   large
# 23          2              6        False   small
# 24          2              6        False   small
# 25          2              6        False   small
# 26          6              0        False   small
# 27          4              0        False   small
# 28          6              4        False   small
# 29          2              0        False   small

# %%
print('Distribuicao por regime de tamanho:')
print(metadata['regime'].value_counts())

print('\nDistribuicao por numero de classes:')
print(metadata['n_classes'].describe())

print('\nDatasets com missing values:', metadata['has_missing'].sum())
# Out:
# Distribuicao por regime de tamanho:
# regime
# small     10
# medium    10
# large     10
# Name: count, dtype: int64
#
# Distribuicao por numero de classes:
# count       30.000000
# mean       619.633333
# std       2141.913719
# min          2.000000
# 25%          2.000000
# 50%          2.000000
# 75%         35.250000
# max      11602.000000
# Name: n_classes, dtype: float64
#
# Datasets com missing values: 0
