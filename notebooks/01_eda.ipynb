# %% [markdown]
# # 01 - EDA dos 30 datasets do TabArena-v0.1
#
# Carrega os 30 datasets configurados em `data/load_tabarena.py` e gera tabela-resumo com tamanho, numero de classes, proporcao numerico/categorico e presenca de missing values. A partir dessa tabela definimos os regimes para a analise da Etapa 2.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from data.load_tabarena import summarize, RECOMMENDED_TASK_IDS

# %%
metadata = summarize(RECOMMENDED_TASK_IDS)
metadata
# Out:
#     task_id                    name  n_samples  n_features  n_classes  \
# 0        11           balance-scale        625           4          3
# 1        14           mfeat-fourier       2000          76         10
# 2        15                breast-w        699           9          2
# 3        16          mfeat-karhunen       2000          64         10
# 4        18     mfeat-morphological       2000           6         10
# 5        22           mfeat-zernike       2000          47         10
# 6        23                     cmc       1473           9          3
# 7        28               optdigits       5620          64         10
# 8        29         credit-approval        690          15          2
# 9        31                credit-g       1000          20          2
# 10       32               pendigits      10992          16         10
# 11       37                diabetes        768           8          2
# 12       43                spambase       4601          57          2
# 13       45                  splice       3190          60          3
# 14       49             tic-tac-toe        958           9          2
# 15      219             electricity      45312           8          2
# 16     2074                satimage       6430          36          6
# 17     3021                    sick       3772          29          2
# 18     3022                   vowel        990          12         11
# 19     3481                  isolet       7797         617         26
# 20     3549  analcatdata_authorship        841          70          4
# 21     3560        analcatdata_dmft        797           4          6
# 22     3902                     pc4       1458          37          2
# 23     3903                     pc3       1563          37          2
# 24     3904                     jm1      10885          21          2
# 25     3913                     kc2        522          21          2
# 26     3917                     kc1       2109          21          2
# 27     3918                     pc1       1109          21          2
# 28     7592                   adult      48842          14          2
# 29     9910             Bioresponse       3751        1776          2
#
#     n_categorical  has_missing  regime
# 0               0        False   small
# 1               0        False  medium
# 2               0         True   small
# 3               0        False  medium
# 4               0        False  medium
# 5               0        False  medium
# 6               7        False  medium
# 7               0        False  medium
# 8               9         True   small
# 9              13        False  medium
# 10              0        False   large
# 11              0        False   small
# 12              0        False  medium
# 13             60        False  medium
# 14              9        False   small
# 15              1        False   large
# 16              0        False  medium
# 17             22         True  medium
# 18              2        False   small
# 19              0        False  medium
# 20              0        False   small
# 21              4        False   small
# 22              0        False  medium
# 23              0        False  medium
# 24              0         True   large
# 25              0        False   small
# 26              0        False  medium
# 27              0        False  medium
# 28              8         True   large
# 29              0        False  medium

# %%
print('Distribuicao por regime de tamanho:')
print(metadata['regime'].value_counts())

print('\nDistribuicao por numero de classes:')
print(metadata['n_classes'].describe())

print('\nDatasets com missing values:', metadata['has_missing'].sum())
# Out:
# Distribuicao por regime de tamanho:
# regime
# medium    17
# small      9
# large      4
# Name: count, dtype: int64
#
# Distribuicao por numero de classes:
# count    30.000000
# mean      5.133333
# std       5.204331
# min       2.000000
# 25%       2.000000
# 50%       2.000000
# 75%       9.000000
# max      26.000000
# Name: n_classes, dtype: float64
#
# Datasets com missing values: 5
